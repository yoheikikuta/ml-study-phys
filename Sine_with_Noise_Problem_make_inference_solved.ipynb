# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import tensorflow as tf 

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
# import utils as ut
# early_stopping = ut.EarlyStopping(patience=100, verbose=1)

# %% [markdown]
# # 1a. Create Data for Toy Problem

# %%
seed_int=123

rng = np.random.RandomState(seed_int)

def sin(x, T=100):
    return np.sin(2.0 * np.pi * x/T)

def toy_problem(T=100, ampl=0.05):
    x = np.arange(0, 2*T + 1)
    noise = ampl*rng.uniform(low = -1.0, high = 1.0, size=len(x))
    return sin(x) + noise

T = 100
f = toy_problem(T)
plt.plot(f)

# %% [markdown]
# # 1b. Prepare Input Data to Train the Model

# %%
length_of_sequences = 2*T
maxlen = 50
# maxlen = 25
data = []
target = []

for i in range(0, length_of_sequences - maxlen + 1):
    data.append(f[i: i + maxlen])
    target.append(f[i + maxlen])

X = np.array(data).reshape(len(data), maxlen, 1)
Y = np.array(target).reshape(len(data), 1)

# %% [markdown]
# # 1b. Split Data into Training and Valdiation Set

# %%
N_train = int(len(data) * 0.9)
N_validation = len(data) - N_train
X_train, X_validation, Y_train, Y_validation = \
train_test_split(X, Y, test_size=N_validation, random_state=seed_int)

# %% [markdown]
# # 2a. Prepare Model Functions for Graph

# %%
def weight_variable(shape, name=None):
    initial = tf.truncated_normal(shape, stddev=0.01) # resample 2 sd vals
    return tf.get_variable(name, dtype=tf.float32, initializer=initial)
    
def bias_variable(shape, name=None, init_fun=tf.zeros):
    initial = init_fun(shape, dtype=tf.float32)
    return tf.get_variable(name, dtype=tf.float32, initializer=initial)

# %% [markdown]
# # 2b. Manual Inference Functions

# %%
def infere_RNN(x, n_batch, maxlen=None, n_hidden=None, n_out=None, n_in=None):
    #########################################################################
    # Write an RNN that takes as input data a matrix x
    # with shape=[n_batch, maxlen, n_in])
    #########################################################################
    return y

def infere_LSTM(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
                n_in=None):
    #########################################################################
    # Write an LSTM that takes as input data a matrix x
    # with shape=[n_batch, maxlen, n_in])
    #########################################################################
    return y, [V, c]

def infere_GRU(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
                n_in=None):
    #########################################################################
    # Write a GRU that takes as input data a matrix x
    # with shape=[n_batch, maxlen, n_in])
    #########################################################################
    return y

# %%
# def infere_RNN(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
#                 n_in=None):
#     V = weight_variable([n_hidden, n_out], 'V')
#     c = bias_variable([n_out], 'c')

#     with tf.variable_scope('RNN'):
#         # going to combine this as (x, U)
#         U = weight_variable([n_in, n_hidden], 'U') 
#         W = weight_variable([n_hidden, n_hidden], 'W')
#         b = bias_variable([n_hidden], 'b')
#         hlist = []
#         h_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
#         for i in range(maxlen):
#             if i > 0:
#                 tf.get_variable_scope().reuse_variables()
#                 h_prev = hlist[-1]
#             h_i = tf.tanh(tf.matmul(x[:, i, :], U) + tf.matmul(h_prev, W) + b)
#             hlist.append(h_i)
#     h_last = hlist[-1]
#     y = tf.matmul(h_last, V) + c
#     return y, [V, U, W, b, c]

def infere_RNN(x, n_batch, maxlen=None, n_hidden=None, n_out=None, n_in=None):
    #########################################################################
    # Write an RNN that takes as input data a matrix x
    # with shape=[n_batch, maxlen, n_in])
    #########################################################################
    V = weight_variable([n_hidden, n_out], 'V')
    c = bias_variable([n_out], 'c')

    with tf.variable_scope('RNN'):
        # going to combine this as (x, U)
        U = weight_variable([n_in, n_hidden], 'U')
        W = weight_variable([n_hidden, n_hidden], 'W')
        b = bias_variable([n_hidden], 'b')
        h_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
        for i in range(maxlen):
            h_prev = tf.tanh(tf.matmul(x[:, i, :], U) + tf.matmul(h_prev, W) + b)
    y = tf.matmul(h_prev, V) + c
    return y, [V, U, W, b, c]

def infere_GRU(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
                n_in=None):
    V = weight_variable([n_hidden, n_out], 'V')
    c = bias_variable([n_out], 'c')

    with tf.variable_scope('GRU'):
        # going to combine this as (x, U)
        # RESET UNITS
        Ur = weight_variable([n_in, n_hidden], 'Ur') 
        Wr = weight_variable([n_hidden, n_hidden], 'Wr')
        br = bias_variable([n_hidden], 'br')
        # UPDATE UNITS
        Uz = weight_variable([n_in, n_hidden], 'Uz') 
        Wz = weight_variable([n_hidden, n_hidden], 'Wz')
        bz = bias_variable([n_hidden], 'bz', init_fun=tf.ones) # limit of the RNN is recovered for f=1, i.e. large bias
        # HIDDEN UNITS (new memory)
        Uh = weight_variable([n_in, n_hidden], 'Uh') 
        Wh = weight_variable([n_hidden, n_hidden], 'Wh')
        bh = bias_variable([n_hidden], 'bh')
        # NEW MEMORY UNITS ('activation' units)
        # Initialize lists
        hlist = []
    
        h_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
        for i in range(maxlen):
            if i > 0:
                tf.get_variable_scope().reuse_variables()
                h_prev = hlist[-1]
            r_i = tf.sigmoid(tf.matmul(x[:, i, :], Ur) + tf.matmul(h_prev, Wr) + br) 
            z_i = tf.sigmoid(tf.matmul(x[:, i, :], Uz) + tf.matmul(h_prev, Wz) + bz) 
            ht_i = tf.tanh(tf.matmul(x[:, i, :], Uh) + r_i*tf.matmul(h_prev, Wh) + bh)
            h_i = z_i*h_prev + (1 - z_i)*ht_i
            hlist.append(h_i)
    h_last = hlist[-1]
    y = tf.matmul(h_last, V) + c
    return y, [V, c]

def infere_LSTM(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
                n_in=None):
    V = weight_variable([n_hidden, n_out], 'V')
    c = bias_variable([n_out], 'c')

    with tf.variable_scope('LSTM'):
        # going to combine this as (x, U)
        # INPUT UNITS
        Ui = weight_variable([n_in, n_hidden], 'Ui') 
        Wi = weight_variable([n_hidden, n_hidden], 'Wi')
        Vi = weight_variable([n_hidden, n_hidden], 'Vi')
        bi = bias_variable([n_hidden], 'bi')
        # OUTPUT UNITS
        Uo = weight_variable([n_in, n_hidden], 'Uo') 
        Wo = weight_variable([n_hidden, n_hidden], 'Wo')
        Vo = weight_variable([n_hidden, n_hidden], 'Vo')
        bo = bias_variable([n_hidden], 'bo')
        # FORGET UNITS
        Uf = weight_variable([n_in, n_hidden], 'Uf') 
        Wf = weight_variable([n_hidden, n_hidden], 'Wf')
        Vf = weight_variable([n_hidden, n_hidden], 'Vf')
        bf = bias_variable([n_hidden], 'bf', init_fun=tf.ones) # limit of the RNN is recovered for f=1, i.e. large bias
        # NEW MEMORY UNITS ('activation' units)
        Ua = weight_variable([n_in, n_hidden], 'Ua') 
        Wa = weight_variable([n_hidden, n_hidden], 'Wa')
        ba = bias_variable([n_hidden], 'ba')
        # Initialize lists
        hlist = []
        clist = []
      
        h_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
        c_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
        for i in range(maxlen):
            if i > 0:
                tf.get_variable_scope().reuse_variables()
                h_prev = hlist[-1]
                c_prev = clist[-1]
            a_i = tf.tanh(   tf.matmul(x[:, i, :], Ua) + tf.matmul(h_prev, Wa)                         + ba)
            f_i = tf.sigmoid(tf.matmul(x[:, i, :], Uf) + tf.matmul(h_prev, Wf) + tf.matmul(c_prev, Vf) + bf) 
            i_i = tf.sigmoid(tf.matmul(x[:, i, :], Ui) + tf.matmul(h_prev, Wi) + tf.matmul(c_prev, Vi) + bi) 
            c_i = i_i * a_i + f_i * c_prev
            o_i = tf.sigmoid(tf.matmul(x[:, i, :], Uo) + tf.matmul(h_prev, Wo) + tf.matmul(c_i, Vo)    + bo)
            h_i = o_i * tf.tanh(c_i)
            hlist.append(h_i)
            clist.append(c_i)
    h_last = hlist[-1]
    y = tf.matmul(h_last, V) + c
    return y, [V, c]

# %% [markdown]
# # 2c. Loss and training function

# %%
def loss_fun(y, t):
    mse = tf.reduce_mean(tf.square(y - t))
    return mse

def training(loss):
    optimize = tf.train.AdamOptimizer(learning_rate = 0.001, beta1=0.9, beta2=0.999)
    train_step = optimize.minimize(loss)
    return train_step

# %% [markdown]
# # 3. Define Graph

# %%
tf.reset_default_graph()

# maxlen = 50
n_hidden = 20
n_out = 1
n_in = 1

x = tf.placeholder(tf.float32, shape=[None, maxlen, n_in])
t = tf.placeholder(tf.float32, shape=[None, n_out])
n_batch = tf.placeholder(tf.int32, [])

# TF Variables
# y = infere_mn(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
y, cvars = infere_RNN(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
# y, cvars = infere_LSTM(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
loss = loss_fun(y, t)
train_step = training(loss)

# %% [markdown]
# # 4. Run Computational Graph

# %%
epochs = 1000
batch_size = 10

tf.set_random_seed(seed_int)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
history= {'val_loss': []}
n_batches = N_train // batch_size
# early_stopping = ut.EarlyStopping(patience=100, verbose=1)
for epoch in range(epochs):
    X_, Y_ = shuffle(X_train, Y_train, random_state = seed_int)
    
    for i in range(n_batches):
        start = i*batch_size
        end = start + batch_size
        
        sess.run(train_step, feed_dict={
            x: X_[start:end],
            t: Y_[start:end],
            n_batch: batch_size
        })
    val_loss = loss.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation
    })
    history['val_loss'].append(val_loss)
    print('epoch:', epoch, ' validation loss: ', val_loss)
    #Early Stopping
#     if early_stopping.validate(val_loss):
#         break
# Out:
# epoch: 0  validation loss:  0.536744
# epoch: 1  validation loss:  0.494941
# epoch: 2  validation loss:  0.330123
# epoch: 3  validation loss:  0.171931
# epoch: 4  validation loss:  0.0898843
# epoch: 5  validation loss:  0.0523216
# epoch: 6  validation loss:  0.0398867
# epoch: 7  validation loss:  0.0328292
# epoch: 8  validation loss:  0.0280827
# epoch: 9  validation loss:  0.0250768
# epoch: 10  validation loss:  0.0225638
# epoch: 11  validation loss:  0.0206912
# epoch: 12  validation loss:  0.0191803
# epoch: 13  validation loss:  0.0179002
# epoch: 14  validation loss:  0.0168321
# epoch: 15  validation loss:  0.0158875
# epoch: 16  validation loss:  0.0150661
# epoch: 17  validation loss:  0.0143334
# epoch: 18  validation loss:  0.0136794
# epoch: 19  validation loss:  0.01309
# epoch: 20  validation loss:  0.0125552
# epoch: 21  validation loss:  0.0120677
# epoch: 22  validation loss:  0.0116207
# epoch: 23  validation loss:  0.0112092
# epoch: 24  validation loss:  0.0108289
# epoch: 25  validation loss:  0.0104761
# epoch: 26  validation loss:  0.0101478
# epoch: 27  validation loss:  0.00984134
# epoch: 28  validation loss:  0.00955451
# epoch: 29  validation loss:  0.00928537
# epoch: 30  validation loss:  0.00903223
# epoch: 31  validation loss:  0.00879359
# epoch: 32  validation loss:  0.00856817
# epoch: 33  validation loss:  0.00835483
# epoch: 34  validation loss:  0.00815253
# epoch: 35  validation loss:  0.00796039
# epoch: 36  validation loss:  0.00777759
# epoch: 37  validation loss:  0.0076034
# epoch: 38  validation loss:  0.00743717
# epoch: 39  validation loss:  0.00727831
# epoch: 40  validation loss:  0.00712629
# epoch: 41  validation loss:  0.00698063
# epoch: 42  validation loss:  0.00684088
# epoch: 43  validation loss:  0.00670665
# epoch: 44  validation loss:  0.00657756
# epoch: 45  validation loss:  0.00645329
# epoch: 46  validation loss:  0.00633353
# epoch: 47  validation loss:  0.00621798
# epoch: 48  validation loss:  0.0061064
# epoch: 49  validation loss:  0.00599855
# epoch: 50  validation loss:  0.00589419
# epoch: 51  validation loss:  0.00579313
# epoch: 52  validation loss:  0.00569519
# epoch: 53  validation loss:  0.00560017
# epoch: 54  validation loss:  0.00550792
# epoch: 55  validation loss:  0.00541829
# epoch: 56  validation loss:  0.00533115
# epoch: 57  validation loss:  0.00524635
# epoch: 58  validation loss:  0.00516379
# epoch: 59  validation loss:  0.00508334
# epoch: 60  validation loss:  0.00500491
# epoch: 61  validation loss:  0.0049284
# epoch: 62  validation loss:  0.00485372
# epoch: 63  validation loss:  0.00478079
# epoch: 64  validation loss:  0.00470954
# epoch: 65  validation loss:  0.00463989
# epoch: 66  validation loss:  0.00457178
# epoch: 67  validation loss:  0.00450516
# epoch: 68  validation loss:  0.00443997
# epoch: 69  validation loss:  0.00437616
# epoch: 70  validation loss:  0.0043137
# epoch: 71  validation loss:  0.00425253
# epoch: 72  validation loss:  0.00419264
# epoch: 73  validation loss:  0.00413399
# epoch: 74  validation loss:  0.00407656
# epoch: 75  validation loss:  0.00402033
# epoch: 76  validation loss:  0.00396528
# epoch: 77  validation loss:  0.0039114
# epoch: 78  validation loss:  0.00385869
# epoch: 79  validation loss:  0.00380715
# epoch: 80  validation loss:  0.00375677
# epoch: 81  validation loss:  0.00370756
# epoch: 82  validation loss:  0.00365954
# epoch: 83  validation loss:  0.00361271
# epoch: 84  validation loss:  0.00356709
# epoch: 85  validation loss:  0.00352271
# epoch: 86  validation loss:  0.00347959
# epoch: 87  validation loss:  0.00343775
# epoch: 88  validation loss:  0.00339725
# epoch: 89  validation loss:  0.0033581
# epoch: 90  validation loss:  0.00332036
# epoch: 91  validation loss:  0.00328406
# epoch: 92  validation loss:  0.00324925
# epoch: 93  validation loss:  0.00321598
# epoch: 94  validation loss:  0.00318432
# epoch: 95  validation loss:  0.00315431
# epoch: 96  validation loss:  0.00312601
# epoch: 97  validation loss:  0.00309951
# epoch: 98  validation loss:  0.00307484
# epoch: 99  validation loss:  0.0030521
# epoch: 100  validation loss:  0.00303134
# epoch: 101  validation loss:  0.00301264
# epoch: 102  validation loss:  0.00299606
# epoch: 103  validation loss:  0.00298169
# epoch: 104  validation loss:  0.00296956
# epoch: 105  validation loss:  0.00295976
# epoch: 106  validation loss:  0.00295232
# epoch: 107  validation loss:  0.00294728
# epoch: 108  validation loss:  0.00294465
# epoch: 109  validation loss:  0.00294443
# epoch: 110  validation loss:  0.00294659
# epoch: 111  validation loss:  0.00295109
# epoch: 112  validation loss:  0.00295783
# epoch: 113  validation loss:  0.00296668
# epoch: 114  validation loss:  0.0029775
# epoch: 115  validation loss:  0.00299009
# epoch: 116  validation loss:  0.00300422
# epoch: 117  validation loss:  0.00301965
# epoch: 118  validation loss:  0.00303609
# epoch: 119  validation loss:  0.00305327
# epoch: 120  validation loss:  0.00307088
# epoch: 121  validation loss:  0.00308864
# epoch: 122  validation loss:  0.00310626
# epoch: 123  validation loss:  0.00312349
# epoch: 124  validation loss:  0.00314011
# epoch: 125  validation loss:  0.00315591
# epoch: 126  validation loss:  0.00317074
# epoch: 127  validation loss:  0.00318449
# epoch: 128  validation loss:  0.00319708
# epoch: 129  validation loss:  0.00320846
# epoch: 130  validation loss:  0.00321862
# epoch: 131  validation loss:  0.00322757
# epoch: 132  validation loss:  0.00323536
# epoch: 133  validation loss:  0.00324203
# epoch: 134  validation loss:  0.00324766
# epoch: 135  validation loss:  0.00325233
# epoch: 136  validation loss:  0.00325611
# epoch: 137  validation loss:  0.0032591
# epoch: 138  validation loss:  0.00326136
# epoch: 139  validation loss:  0.00326299
# epoch: 140  validation loss:  0.00326405
# epoch: 141  validation loss:  0.00326461
# epoch: 142  validation loss:  0.00326474
# epoch: 143  validation loss:  0.00326451
# epoch: 144  validation loss:  0.00326395
# epoch: 145  validation loss:  0.00326313
# epoch: 146  validation loss:  0.00326207
# epoch: 147  validation loss:  0.00326083
# epoch: 148  validation loss:  0.00325942
# epoch: 149  validation loss:  0.00325789
# epoch: 150  validation loss:  0.00325625
# epoch: 151  validation loss:  0.00325452
# epoch: 152  validation loss:  0.00325273
# epoch: 153  validation loss:  0.00325088
# epoch: 154  validation loss:  0.00324899
# epoch: 155  validation loss:  0.00324708
# epoch: 156  validation loss:  0.00324514
# epoch: 157  validation loss:  0.00324319
# epoch: 158  validation loss:  0.00324123
# epoch: 159  validation loss:  0.00323928
# epoch: 160  validation loss:  0.00323732
# epoch: 161  validation loss:  0.00323537
# epoch: 162  validation loss:  0.00323343
# epoch: 163  validation loss:  0.00323149
# epoch: 164  validation loss:  0.00322956
# epoch: 165  validation loss:  0.00322765
# epoch: 166  validation loss:  0.00322575
# epoch: 167  validation loss:  0.00322386
# epoch: 168  validation loss:  0.00322198
# epoch: 169  validation loss:  0.00322011
# epoch: 170  validation loss:  0.00321825
# epoch: 171  validation loss:  0.00321641
# epoch: 172  validation loss:  0.00321456
# epoch: 173  validation loss:  0.00321274
# epoch: 174  validation loss:  0.00321091
# epoch: 175  validation loss:  0.00320911
# epoch: 176  validation loss:  0.0032073
# epoch: 177  validation loss:  0.0032055
# epoch: 178  validation loss:  0.00320371
# epoch: 179  validation loss:  0.00320192
# epoch: 180  validation loss:  0.00320013
# epoch: 181  validation loss:  0.00319834
# epoch: 182  validation loss:  0.00319656
# epoch: 183  validation loss:  0.00319478
# epoch: 184  validation loss:  0.003193
# epoch: 185  validation loss:  0.00319121
# epoch: 186  validation loss:  0.00318943
# epoch: 187  validation loss:  0.00318764
# epoch: 188  validation loss:  0.00318585
# epoch: 189  validation loss:  0.00318406
# epoch: 190  validation loss:  0.00318226
# epoch: 191  validation loss:  0.00318046
# epoch: 192  validation loss:  0.00317865
# epoch: 193  validation loss:  0.00317683
# epoch: 194  validation loss:  0.00317501
# epoch: 195  validation loss:  0.00317319
# epoch: 196  validation loss:  0.00317136
# epoch: 197  validation loss:  0.00316951
# epoch: 198  validation loss:  0.00316766
# epoch: 199  validation loss:  0.0031658
# epoch: 200  validation loss:  0.00316393
# epoch: 201  validation loss:  0.00316205
# epoch: 202  validation loss:  0.00316016
# epoch: 203  validation loss:  0.00315826
# epoch: 204  validation loss:  0.00315635
# epoch: 205  validation loss:  0.00315443
# epoch: 206  validation loss:  0.00315249
# epoch: 207  validation loss:  0.00315055
# epoch: 208  validation loss:  0.00314859
# epoch: 209  validation loss:  0.00314662
# epoch: 210  validation loss:  0.00314463
# epoch: 211  validation loss:  0.00314264
# epoch: 212  validation loss:  0.00314063
# epoch: 213  validation loss:  0.00313861
# epoch: 214  validation loss:  0.00313657
# epoch: 215  validation loss:  0.00313452
# epoch: 216  validation loss:  0.00313246
# epoch: 217  validation loss:  0.00313038
# epoch: 218  validation loss:  0.00312828
# epoch: 219  validation loss:  0.00312618
# epoch: 220  validation loss:  0.00312406
# epoch: 221  validation loss:  0.00312192
# epoch: 222  validation loss:  0.00311977
# epoch: 223  validation loss:  0.0031176
# epoch: 224  validation loss:  0.00311542
# epoch: 225  validation loss:  0.00311322
# epoch: 226  validation loss:  0.00311101
# epoch: 227  validation loss:  0.00310878
# epoch: 228  validation loss:  0.00310654
# epoch: 229  validation loss:  0.00310428
# epoch: 230  validation loss:  0.00310201
# epoch: 231  validation loss:  0.00309972
# epoch: 232  validation loss:  0.00309741
# epoch: 233  validation loss:  0.00309509
# epoch: 234  validation loss:  0.00309275
# epoch: 235  validation loss:  0.0030904
# epoch: 236  validation loss:  0.00308802
# epoch: 237  validation loss:  0.00308563
# epoch: 238  validation loss:  0.00308323
# epoch: 239  validation loss:  0.00308081
# epoch: 240  validation loss:  0.00307837
# epoch: 241  validation loss:  0.00307592
# epoch: 242  validation loss:  0.00307345
# epoch: 243  validation loss:  0.00307096
# epoch: 244  validation loss:  0.00306845
# epoch: 245  validation loss:  0.00306593
# epoch: 246  validation loss:  0.00306339
# epoch: 247  validation loss:  0.00306084
# epoch: 248  validation loss:  0.00305826
# epoch: 249  validation loss:  0.00305567
# epoch: 250  validation loss:  0.00305306
# epoch: 251  validation loss:  0.00305044
# epoch: 252  validation loss:  0.00304779
# epoch: 253  validation loss:  0.00304513
# epoch: 254  validation loss:  0.00304245
# epoch: 255  validation loss:  0.00303975
# epoch: 256  validation loss:  0.00303704
# epoch: 257  validation loss:  0.0030343
# epoch: 258  validation loss:  0.00303155
# epoch: 259  validation loss:  0.00302878
# epoch: 260  validation loss:  0.003026
# epoch: 261  validation loss:  0.00302319
# epoch: 262  validation loss:  0.00302037
# epoch: 263  validation loss:  0.00301753
# epoch: 264  validation loss:  0.00301466
# epoch: 265  validation loss:  0.00301178
# epoch: 266  validation loss:  0.00300889
# epoch: 267  validation loss:  0.00300597
# epoch: 268  validation loss:  0.00300303
# epoch: 269  validation loss:  0.00300008
# epoch: 270  validation loss:  0.00299711
# epoch: 271  validation loss:  0.00299411
# epoch: 272  validation loss:  0.0029911
# epoch: 273  validation loss:  0.00298807
# epoch: 274  validation loss:  0.00298502
# epoch: 275  validation loss:  0.00298195
# epoch: 276  validation loss:  0.00297887
# epoch: 277  validation loss:  0.00297576
# epoch: 278  validation loss:  0.00297263
# epoch: 279  validation loss:  0.00296949
# epoch: 280  validation loss:  0.00296632
# epoch: 281  validation loss:  0.00296314
# epoch: 282  validation loss:  0.00295993
# epoch: 283  validation loss:  0.00295671
# epoch: 284  validation loss:  0.00295347
# epoch: 285  validation loss:  0.0029502
# epoch: 286  validation loss:  0.00294692
# epoch: 287  validation loss:  0.00294363
# epoch: 288  validation loss:  0.00294031
# epoch: 289  validation loss:  0.00293696
# epoch: 290  validation loss:  0.00293361
# epoch: 291  validation loss:  0.00293023
# epoch: 292  validation loss:  0.00292683
# epoch: 293  validation loss:  0.00292342
# epoch: 294  validation loss:  0.00291998
# epoch: 295  validation loss:  0.00291652
# epoch: 296  validation loss:  0.00291305
# epoch: 297  validation loss:  0.00290956
# epoch: 298  validation loss:  0.00290605
# epoch: 299  validation loss:  0.00290252
# epoch: 300  validation loss:  0.00289897
# epoch: 301  validation loss:  0.0028954
# epoch: 302  validation loss:  0.00289181
# epoch: 303  validation loss:  0.00288821
# epoch: 304  validation loss:  0.00288459
# epoch: 305  validation loss:  0.00288095
# epoch: 306  validation loss:  0.00287729
# epoch: 307  validation loss:  0.00287362
# epoch: 308  validation loss:  0.00286992
# epoch: 309  validation loss:  0.0028662
# epoch: 310  validation loss:  0.00286248
# epoch: 311  validation loss:  0.00285874
# epoch: 312  validation loss:  0.00285497
# epoch: 313  validation loss:  0.00285119
# epoch: 314  validation loss:  0.0028474
# epoch: 315  validation loss:  0.00284359
# epoch: 316  validation loss:  0.00283976
# epoch: 317  validation loss:  0.00283592
# epoch: 318  validation loss:  0.00283206
# epoch: 319  validation loss:  0.00282818
# epoch: 320  validation loss:  0.00282429
# epoch: 321  validation loss:  0.00282039
# epoch: 322  validation loss:  0.00281647
# epoch: 323  validation loss:  0.00281253
# epoch: 324  validation loss:  0.00280859
# epoch: 325  validation loss:  0.00280462
# epoch: 326  validation loss:  0.00280064
# epoch: 327  validation loss:  0.00279666
# epoch: 328  validation loss:  0.00279266
# epoch: 329  validation loss:  0.00278864
# epoch: 330  validation loss:  0.00278461
# epoch: 331  validation loss:  0.00278057
# epoch: 332  validation loss:  0.00277652
# epoch: 333  validation loss:  0.00277246
# epoch: 334  validation loss:  0.00276838
# epoch: 335  validation loss:  0.0027643
# epoch: 336  validation loss:  0.0027602
# epoch: 337  validation loss:  0.00275609
# epoch: 338  validation loss:  0.00275198
# epoch: 339  validation loss:  0.00274785
# epoch: 340  validation loss:  0.00274371
# epoch: 341  validation loss:  0.00273957
# epoch: 342  validation loss:  0.00273541
# epoch: 343  validation loss:  0.00273125
# epoch: 344  validation loss:  0.00272708
# epoch: 345  validation loss:  0.00272289
# epoch: 346  validation loss:  0.00271871
# epoch: 347  validation loss:  0.00271451
# epoch: 348  validation loss:  0.0027103
# epoch: 349  validation loss:  0.00270609
# epoch: 350  validation loss:  0.00270187
# epoch: 351  validation loss:  0.00269765
# epoch: 352  validation loss:  0.00269342
# epoch: 353  validation loss:  0.00268918
# epoch: 354  validation loss:  0.00268493
# epoch: 355  validation loss:  0.00268068
# epoch: 356  validation loss:  0.00267642
# epoch: 357  validation loss:  0.00267216
# epoch: 358  validation loss:  0.00266789
# epoch: 359  validation loss:  0.00266362
# epoch: 360  validation loss:  0.00265934
# epoch: 361  validation loss:  0.00265505
# epoch: 362  validation loss:  0.00265076
# epoch: 363  validation loss:  0.00264647
# epoch: 364  validation loss:  0.00264217
# epoch: 365  validation loss:  0.00263786
# epoch: 366  validation loss:  0.00263355
# epoch: 367  validation loss:  0.00262924
# epoch: 368  validation loss:  0.00262492
# epoch: 369  validation loss:  0.00262059
# epoch: 370  validation loss:  0.00261626
# epoch: 371  validation loss:  0.00261193
# epoch: 372  validation loss:  0.00260759
# epoch: 373  validation loss:  0.00260324
# epoch: 374  validation loss:  0.00259889
# epoch: 375  validation loss:  0.00259454
# epoch: 376  validation loss:  0.00259018
# epoch: 377  validation loss:  0.00258581
# epoch: 378  validation loss:  0.00258144
# epoch: 379  validation loss:  0.00257706
# epoch: 380  validation loss:  0.00257267
# epoch: 381  validation loss:  0.00256828
# epoch: 382  validation loss:  0.00256388
# epoch: 383  validation loss:  0.00255947
# epoch: 384  validation loss:  0.00255506
# epoch: 385  validation loss:  0.00255063
# epoch: 386  validation loss:  0.0025462
# epoch: 387  validation loss:  0.00254176
# epoch: 388  validation loss:  0.00253731
# epoch: 389  validation loss:  0.00253285
# epoch: 390  validation loss:  0.00252839
# epoch: 391  validation loss:  0.00252391
# epoch: 392  validation loss:  0.00251942
# epoch: 393  validation loss:  0.00251492
# epoch: 394  validation loss:  0.00251041
# epoch: 395  validation loss:  0.00250588
# epoch: 396  validation loss:  0.00250134
# epoch: 397  validation loss:  0.00249679
# epoch: 398  validation loss:  0.00249222
# epoch: 399  validation loss:  0.00248764
# epoch: 400  validation loss:  0.00248305
# epoch: 401  validation loss:  0.00247844
# epoch: 402  validation loss:  0.00247381
# epoch: 403  validation loss:  0.00246916
# epoch: 404  validation loss:  0.0024645
# epoch: 405  validation loss:  0.00245982
# epoch: 406  validation loss:  0.00245511
# epoch: 407  validation loss:  0.00245039
# epoch: 408  validation loss:  0.00244566
# epoch: 409  validation loss:  0.00244089
# epoch: 410  validation loss:  0.00243611
# epoch: 411  validation loss:  0.0024313
# epoch: 412  validation loss:  0.00242647
# epoch: 413  validation loss:  0.00242161
# epoch: 414  validation loss:  0.00241673
# epoch: 415  validation loss:  0.00241182
# epoch: 416  validation loss:  0.00240689
# epoch: 417  validation loss:  0.00240193
# epoch: 418  validation loss:  0.00239694
# epoch: 419  validation loss:  0.00239192
# epoch: 420  validation loss:  0.00238687
# epoch: 421  validation loss:  0.00238178
# epoch: 422  validation loss:  0.00237667
# epoch: 423  validation loss:  0.00237152
# epoch: 424  validation loss:  0.00236634
# epoch: 425  validation loss:  0.00236112
# epoch: 426  validation loss:  0.00235587
# epoch: 427  validation loss:  0.00235057
# epoch: 428  validation loss:  0.00234524
# epoch: 429  validation loss:  0.00233986
# epoch: 430  validation loss:  0.00233444
# epoch: 431  validation loss:  0.00232897
# epoch: 432  validation loss:  0.00232346
# epoch: 433  validation loss:  0.0023179
# epoch: 434  validation loss:  0.00231229
# epoch: 435  validation loss:  0.00230662
# epoch: 436  validation loss:  0.0023009
# epoch: 437  validation loss:  0.00229511
# epoch: 438  validation loss:  0.00228927
# epoch: 439  validation loss:  0.00228337
# epoch: 440  validation loss:  0.00227739
# epoch: 441  validation loss:  0.00227134
# epoch: 442  validation loss:  0.00226522
# epoch: 443  validation loss:  0.00225903
# epoch: 444  validation loss:  0.00225274
# epoch: 445  validation loss:  0.00224638
# epoch: 446  validation loss:  0.00223993
# epoch: 447  validation loss:  0.0022334
# epoch: 448  validation loss:  0.00222677
# epoch: 449  validation loss:  0.00222005
# epoch: 450  validation loss:  0.00221325
# epoch: 451  validation loss:  0.00220635
# epoch: 452  validation loss:  0.00219939
# epoch: 453  validation loss:  0.00219236
# epoch: 454  validation loss:  0.00218528
# epoch: 455  validation loss:  0.00217817
# epoch: 456  validation loss:  0.00217107
# epoch: 457  validation loss:  0.002164
# epoch: 458  validation loss:  0.00215697
# epoch: 459  validation loss:  0.00214999
# epoch: 460  validation loss:  0.002143
# epoch: 461  validation loss:  0.00213578
# epoch: 462  validation loss:  0.00212795
# epoch: 463  validation loss:  0.00211876
# epoch: 464  validation loss:  0.00210702
# epoch: 465  validation loss:  0.00209112
# epoch: 466  validation loss:  0.00206935
# epoch: 467  validation loss:  0.00204043
# epoch: 468  validation loss:  0.00200445
# epoch: 469  validation loss:  0.00196373
# epoch: 470  validation loss:  0.00192367
# epoch: 471  validation loss:  0.00189187
# epoch: 472  validation loss:  0.00187528
# epoch: 473  validation loss:  0.00187647
# epoch: 474  validation loss:  0.00188957
# epoch: 475  validation loss:  0.00190085
# epoch: 476  validation loss:  0.00189987
# epoch: 477  validation loss:  0.00188816
# epoch: 478  validation loss:  0.00187387
# epoch: 479  validation loss:  0.00186292
# epoch: 480  validation loss:  0.00185706
# epoch: 481  validation loss:  0.00185548
# epoch: 482  validation loss:  0.0018559
# epoch: 483  validation loss:  0.00185551
# epoch: 484  validation loss:  0.00185275
# epoch: 485  validation loss:  0.00184806
# epoch: 486  validation loss:  0.0018429
# epoch: 487  validation loss:  0.00183847
# epoch: 488  validation loss:  0.00183517
# epoch: 489  validation loss:  0.00183278
# epoch: 490  validation loss:  0.00183078
# epoch: 491  validation loss:  0.00182864
# epoch: 492  validation loss:  0.00182612
# epoch: 493  validation loss:  0.00182332
# epoch: 494  validation loss:  0.00182049
# epoch: 495  validation loss:  0.00181782
# epoch: 496  validation loss:  0.00181539
# epoch: 497  validation loss:  0.00181315
# epoch: 498  validation loss:  0.00181102
# epoch: 499  validation loss:  0.0018089
# epoch: 500  validation loss:  0.00180675
# epoch: 501  validation loss:  0.0018046
# epoch: 502  validation loss:  0.00180246
# epoch: 503  validation loss:  0.00180038
# epoch: 504  validation loss:  0.00179836
# epoch: 505  validation loss:  0.0017964
# epoch: 506  validation loss:  0.00179447
# epoch: 507  validation loss:  0.00179257
# epoch: 508  validation loss:  0.00179069
# epoch: 509  validation loss:  0.00178884
# epoch: 510  validation loss:  0.001787
# epoch: 511  validation loss:  0.00178519
# epoch: 512  validation loss:  0.0017834
# epoch: 513  validation loss:  0.00178163
# epoch: 514  validation loss:  0.00177989
# epoch: 515  validation loss:  0.00177818
# epoch: 516  validation loss:  0.00177647
# epoch: 517  validation loss:  0.00177479
# epoch: 518  validation loss:  0.00177312
# epoch: 519  validation loss:  0.00177146
# epoch: 520  validation loss:  0.00176982
# epoch: 521  validation loss:  0.0017682
# epoch: 522  validation loss:  0.00176658
# epoch: 523  validation loss:  0.00176499
# epoch: 524  validation loss:  0.0017634
# epoch: 525  validation loss:  0.00176182
# epoch: 526  validation loss:  0.00176026
# epoch: 527  validation loss:  0.0017587
# epoch: 528  validation loss:  0.00175716
# epoch: 529  validation loss:  0.00175563
# epoch: 530  validation loss:  0.00175411
# epoch: 531  validation loss:  0.00175259
# epoch: 532  validation loss:  0.00175109
# epoch: 533  validation loss:  0.00174959
# epoch: 534  validation loss:  0.0017481
# epoch: 535  validation loss:  0.00174661
# epoch: 536  validation loss:  0.00174514
# epoch: 537  validation loss:  0.00174367
# epoch: 538  validation loss:  0.00174221
# epoch: 539  validation loss:  0.00174075
# epoch: 540  validation loss:  0.00173931
# epoch: 541  validation loss:  0.00173786
# epoch: 542  validation loss:  0.00173643
# epoch: 543  validation loss:  0.001735
# epoch: 544  validation loss:  0.00173357
# epoch: 545  validation loss:  0.00173216
# epoch: 546  validation loss:  0.00173074
# epoch: 547  validation loss:  0.00172933
# epoch: 548  validation loss:  0.00172792
# epoch: 549  validation loss:  0.00172652
# epoch: 550  validation loss:  0.00172512
# epoch: 551  validation loss:  0.00172374
# epoch: 552  validation loss:  0.00172235
# epoch: 553  validation loss:  0.00172097
# epoch: 554  validation loss:  0.00171959
# epoch: 555  validation loss:  0.00171822
# epoch: 556  validation loss:  0.00171685
# epoch: 557  validation loss:  0.00171549
# epoch: 558  validation loss:  0.00171412
# epoch: 559  validation loss:  0.00171276
# epoch: 560  validation loss:  0.00171141
# epoch: 561  validation loss:  0.00171006
# epoch: 562  validation loss:  0.00170871
# epoch: 563  validation loss:  0.00170737
# epoch: 564  validation loss:  0.00170604
# epoch: 565  validation loss:  0.0017047
# epoch: 566  validation loss:  0.00170337
# epoch: 567  validation loss:  0.00170204
# epoch: 568  validation loss:  0.00170071
# epoch: 569  validation loss:  0.00169939
# epoch: 570  validation loss:  0.00169807
# epoch: 571  validation loss:  0.00169676
# epoch: 572  validation loss:  0.00169544
# epoch: 573  validation loss:  0.00169413
# epoch: 574  validation loss:  0.00169283
# epoch: 575  validation loss:  0.00169153
# epoch: 576  validation loss:  0.00169023
# epoch: 577  validation loss:  0.00168893
# epoch: 578  validation loss:  0.00168764
# epoch: 579  validation loss:  0.00168635
# epoch: 580  validation loss:  0.00168506
# epoch: 581  validation loss:  0.00168378
# epoch: 582  validation loss:  0.0016825
# epoch: 583  validation loss:  0.00168123
# epoch: 584  validation loss:  0.00167995
# epoch: 585  validation loss:  0.00167868
# epoch: 586  validation loss:  0.00167741
# epoch: 587  validation loss:  0.00167615
# epoch: 588  validation loss:  0.00167488
# epoch: 589  validation loss:  0.00167363
# epoch: 590  validation loss:  0.00167237
# epoch: 591  validation loss:  0.00167112
# epoch: 592  validation loss:  0.00166987
# epoch: 593  validation loss:  0.00166862
# epoch: 594  validation loss:  0.00166738
# epoch: 595  validation loss:  0.00166614
# epoch: 596  validation loss:  0.0016649
# epoch: 597  validation loss:  0.00166367
# epoch: 598  validation loss:  0.00166244
# epoch: 599  validation loss:  0.00166121
# epoch: 600  validation loss:  0.00165998
# epoch: 601  validation loss:  0.00165876
# epoch: 602  validation loss:  0.00165754
# epoch: 603  validation loss:  0.00165632
# epoch: 604  validation loss:  0.00165511
# epoch: 605  validation loss:  0.00165389
# epoch: 606  validation loss:  0.00165268
# epoch: 607  validation loss:  0.00165148
# epoch: 608  validation loss:  0.00165028
# epoch: 609  validation loss:  0.00164908
# epoch: 610  validation loss:  0.00164789
# epoch: 611  validation loss:  0.00164669
# epoch: 612  validation loss:  0.0016455
# epoch: 613  validation loss:  0.00164431
# epoch: 614  validation loss:  0.00164313
# epoch: 615  validation loss:  0.00164195
# epoch: 616  validation loss:  0.00164077
# epoch: 617  validation loss:  0.00163959
# epoch: 618  validation loss:  0.00163842
# epoch: 619  validation loss:  0.00163725
# epoch: 620  validation loss:  0.00163608
# epoch: 621  validation loss:  0.00163492
# epoch: 622  validation loss:  0.00163375
# epoch: 623  validation loss:  0.00163259
# epoch: 624  validation loss:  0.00163143
# epoch: 625  validation loss:  0.00163028
# epoch: 626  validation loss:  0.00162913
# epoch: 627  validation loss:  0.00162799
# epoch: 628  validation loss:  0.00162685
# epoch: 629  validation loss:  0.0016257
# epoch: 630  validation loss:  0.00162456
# epoch: 631  validation loss:  0.00162342
# epoch: 632  validation loss:  0.00162228
# epoch: 633  validation loss:  0.00162115
# epoch: 634  validation loss:  0.00162003
# epoch: 635  validation loss:  0.0016189
# epoch: 636  validation loss:  0.00161778
# epoch: 637  validation loss:  0.00161666
# epoch: 638  validation loss:  0.00161554
# epoch: 639  validation loss:  0.00161443
# epoch: 640  validation loss:  0.00161331
# epoch: 641  validation loss:  0.0016122
# epoch: 642  validation loss:  0.0016111
# epoch: 643  validation loss:  0.00160999
# epoch: 644  validation loss:  0.00160889
# epoch: 645  validation loss:  0.00160779
# epoch: 646  validation loss:  0.00160669
# epoch: 647  validation loss:  0.0016056
# epoch: 648  validation loss:  0.00160451
# epoch: 649  validation loss:  0.00160342
# epoch: 650  validation loss:  0.00160233
# epoch: 651  validation loss:  0.00160125
# epoch: 652  validation loss:  0.00160017
# epoch: 653  validation loss:  0.00159909
# epoch: 654  validation loss:  0.00159801
# epoch: 655  validation loss:  0.00159694
# epoch: 656  validation loss:  0.00159587
# epoch: 657  validation loss:  0.0015948
# epoch: 658  validation loss:  0.00159373
# epoch: 659  validation loss:  0.00159267
# epoch: 660  validation loss:  0.00159161
# epoch: 661  validation loss:  0.00159055
# epoch: 662  validation loss:  0.00158949
# epoch: 663  validation loss:  0.00158843
# epoch: 664  validation loss:  0.00158738
# epoch: 665  validation loss:  0.00158633
# epoch: 666  validation loss:  0.00158529
# epoch: 667  validation loss:  0.00158424
# epoch: 668  validation loss:  0.0015832
# epoch: 669  validation loss:  0.00158216
# epoch: 670  validation loss:  0.00158112
# epoch: 671  validation loss:  0.00158008
# epoch: 672  validation loss:  0.00157905
# epoch: 673  validation loss:  0.00157802
# epoch: 674  validation loss:  0.00157698
# epoch: 675  validation loss:  0.00157596
# epoch: 676  validation loss:  0.00157493
# epoch: 677  validation loss:  0.00157391
# epoch: 678  validation loss:  0.00157289
# epoch: 679  validation loss:  0.00157187
# epoch: 680  validation loss:  0.00157085
# epoch: 681  validation loss:  0.00156984
# epoch: 682  validation loss:  0.00156883
# epoch: 683  validation loss:  0.00156782
# epoch: 684  validation loss:  0.00156681
# epoch: 685  validation loss:  0.0015658
# epoch: 686  validation loss:  0.00156479
# epoch: 687  validation loss:  0.00156379
# epoch: 688  validation loss:  0.00156279
# epoch: 689  validation loss:  0.0015618
# epoch: 690  validation loss:  0.0015608
# epoch: 691  validation loss:  0.00155981
# epoch: 692  validation loss:  0.00155881
# epoch: 693  validation loss:  0.00155782
# epoch: 694  validation loss:  0.00155683
# epoch: 695  validation loss:  0.00155584
# epoch: 696  validation loss:  0.00155486
# epoch: 697  validation loss:  0.00155388
# epoch: 698  validation loss:  0.00155289
# epoch: 699  validation loss:  0.00155191
# epoch: 700  validation loss:  0.00155094
# epoch: 701  validation loss:  0.00154996
# epoch: 702  validation loss:  0.00154898
# epoch: 703  validation loss:  0.00154801
# epoch: 704  validation loss:  0.00154704
# epoch: 705  validation loss:  0.00154607
# epoch: 706  validation loss:  0.0015451
# epoch: 707  validation loss:  0.00154414
# epoch: 708  validation loss:  0.00154317
# epoch: 709  validation loss:  0.00154221
# epoch: 710  validation loss:  0.00154124
# epoch: 711  validation loss:  0.00154028
# epoch: 712  validation loss:  0.00153932
# epoch: 713  validation loss:  0.00153837
# epoch: 714  validation loss:  0.00153741
# epoch: 715  validation loss:  0.00153646
# epoch: 716  validation loss:  0.00153551
# epoch: 717  validation loss:  0.00153456
# epoch: 718  validation loss:  0.00153361
# epoch: 719  validation loss:  0.00153266
# epoch: 720  validation loss:  0.00153171
# epoch: 721  validation loss:  0.00153077
# epoch: 722  validation loss:  0.00152982
# epoch: 723  validation loss:  0.00152888
# epoch: 724  validation loss:  0.00152794
# epoch: 725  validation loss:  0.001527
# epoch: 726  validation loss:  0.00152606
# epoch: 727  validation loss:  0.00152512
# epoch: 728  validation loss:  0.00152418
# epoch: 729  validation loss:  0.00152325
# epoch: 730  validation loss:  0.00152232
# epoch: 731  validation loss:  0.00152138
# epoch: 732  validation loss:  0.00152045
# epoch: 733  validation loss:  0.00151952
# epoch: 734  validation loss:  0.00151859
# epoch: 735  validation loss:  0.00151766
# epoch: 736  validation loss:  0.00151674
# epoch: 737  validation loss:  0.00151581
# epoch: 738  validation loss:  0.00151489
# epoch: 739  validation loss:  0.00151396
# epoch: 740  validation loss:  0.00151304
# epoch: 741  validation loss:  0.00151212
# epoch: 742  validation loss:  0.0015112
# epoch: 743  validation loss:  0.00151028
# epoch: 744  validation loss:  0.00150936
# epoch: 745  validation loss:  0.00150844
# epoch: 746  validation loss:  0.00150753
# epoch: 747  validation loss:  0.00150661
# epoch: 748  validation loss:  0.0015057
# epoch: 749  validation loss:  0.00150478
# epoch: 750  validation loss:  0.00150387
# epoch: 751  validation loss:  0.00150296
# epoch: 752  validation loss:  0.00150204
# epoch: 753  validation loss:  0.00150113
# epoch: 754  validation loss:  0.00150022
# epoch: 755  validation loss:  0.00149931
# epoch: 756  validation loss:  0.00149841
# epoch: 757  validation loss:  0.0014975
# epoch: 758  validation loss:  0.0014966
# epoch: 759  validation loss:  0.00149569
# epoch: 760  validation loss:  0.00149478
# epoch: 761  validation loss:  0.00149388
# epoch: 762  validation loss:  0.00149298
# epoch: 763  validation loss:  0.00149207
# epoch: 764  validation loss:  0.00149117
# epoch: 765  validation loss:  0.00149027
# epoch: 766  validation loss:  0.00148937
# epoch: 767  validation loss:  0.00148847
# epoch: 768  validation loss:  0.00148757
# epoch: 769  validation loss:  0.00148667
# epoch: 770  validation loss:  0.00148578
# epoch: 771  validation loss:  0.00148488
# epoch: 772  validation loss:  0.00148398
# epoch: 773  validation loss:  0.00148308
# epoch: 774  validation loss:  0.00148219
# epoch: 775  validation loss:  0.0014813
# epoch: 776  validation loss:  0.0014804
# epoch: 777  validation loss:  0.0014795
# epoch: 778  validation loss:  0.00147861
# epoch: 779  validation loss:  0.00147772
# epoch: 780  validation loss:  0.00147683
# epoch: 781  validation loss:  0.00147593
# epoch: 782  validation loss:  0.00147504
# epoch: 783  validation loss:  0.00147415
# epoch: 784  validation loss:  0.00147326
# epoch: 785  validation loss:  0.00147237
# epoch: 786  validation loss:  0.00147148
# epoch: 787  validation loss:  0.00147059
# epoch: 788  validation loss:  0.0014697
# epoch: 789  validation loss:  0.00146881
# epoch: 790  validation loss:  0.00146793
# epoch: 791  validation loss:  0.00146705
# epoch: 792  validation loss:  0.00146615
# epoch: 793  validation loss:  0.00146527
# epoch: 794  validation loss:  0.00146438
# epoch: 795  validation loss:  0.00146349
# epoch: 796  validation loss:  0.00146261
# epoch: 797  validation loss:  0.00146173
# epoch: 798  validation loss:  0.00146085
# epoch: 799  validation loss:  0.00145996
# epoch: 800  validation loss:  0.00145907
# epoch: 801  validation loss:  0.00145819
# epoch: 802  validation loss:  0.00145731
# epoch: 803  validation loss:  0.00145643
# epoch: 804  validation loss:  0.00145555
# epoch: 805  validation loss:  0.00145467
# epoch: 806  validation loss:  0.00145378
# epoch: 807  validation loss:  0.0014529
# epoch: 808  validation loss:  0.00145202
# epoch: 809  validation loss:  0.00145114
# epoch: 810  validation loss:  0.00145026
# epoch: 811  validation loss:  0.00144938
# epoch: 812  validation loss:  0.00144851
# epoch: 813  validation loss:  0.00144763
# epoch: 814  validation loss:  0.00144675
# epoch: 815  validation loss:  0.00144587
# epoch: 816  validation loss:  0.001445
# epoch: 817  validation loss:  0.00144412
# epoch: 818  validation loss:  0.00144324
# epoch: 819  validation loss:  0.00144237
# epoch: 820  validation loss:  0.0014415
# epoch: 821  validation loss:  0.00144062
# epoch: 822  validation loss:  0.00143975
# epoch: 823  validation loss:  0.00143888
# epoch: 824  validation loss:  0.001438
# epoch: 825  validation loss:  0.00143713
# epoch: 826  validation loss:  0.00143626
# epoch: 827  validation loss:  0.00143539
# epoch: 828  validation loss:  0.00143452
# epoch: 829  validation loss:  0.00143365
# epoch: 830  validation loss:  0.00143278
# epoch: 831  validation loss:  0.00143191
# epoch: 832  validation loss:  0.00143105
# epoch: 833  validation loss:  0.00143018
# epoch: 834  validation loss:  0.00142931
# epoch: 835  validation loss:  0.00142845
# epoch: 836  validation loss:  0.00142759
# epoch: 837  validation loss:  0.00142672
# epoch: 838  validation loss:  0.00142586
# epoch: 839  validation loss:  0.001425
# epoch: 840  validation loss:  0.00142414
# epoch: 841  validation loss:  0.00142327
# epoch: 842  validation loss:  0.00142241
# epoch: 843  validation loss:  0.00142156
# epoch: 844  validation loss:  0.0014207
# epoch: 845  validation loss:  0.00141985
# epoch: 846  validation loss:  0.00141899
# epoch: 847  validation loss:  0.00141813
# epoch: 848  validation loss:  0.00141728
# epoch: 849  validation loss:  0.00141643
# epoch: 850  validation loss:  0.00141558
# epoch: 851  validation loss:  0.00141473
# epoch: 852  validation loss:  0.00141389
# epoch: 853  validation loss:  0.00141304
# epoch: 854  validation loss:  0.00141219
# epoch: 855  validation loss:  0.00141135
# epoch: 856  validation loss:  0.00141051
# epoch: 857  validation loss:  0.00140967
# epoch: 858  validation loss:  0.00140883
# epoch: 859  validation loss:  0.00140799
# epoch: 860  validation loss:  0.00140716
# epoch: 861  validation loss:  0.00140632
# epoch: 862  validation loss:  0.00140549
# epoch: 863  validation loss:  0.00140466
# epoch: 864  validation loss:  0.00140383
# epoch: 865  validation loss:  0.00140301
# epoch: 866  validation loss:  0.00140219
# epoch: 867  validation loss:  0.00140136
# epoch: 868  validation loss:  0.00140055
# epoch: 869  validation loss:  0.00139973
# epoch: 870  validation loss:  0.00139891
# epoch: 871  validation loss:  0.0013981
# epoch: 872  validation loss:  0.00139729
# epoch: 873  validation loss:  0.00139648
# epoch: 874  validation loss:  0.00139568
# epoch: 875  validation loss:  0.00139487
# epoch: 876  validation loss:  0.00139408
# epoch: 877  validation loss:  0.00139328
# epoch: 878  validation loss:  0.00139248
# epoch: 879  validation loss:  0.00139169
# epoch: 880  validation loss:  0.0013909
# epoch: 881  validation loss:  0.00139012
# epoch: 882  validation loss:  0.00138934
# epoch: 883  validation loss:  0.00138856
# epoch: 884  validation loss:  0.00138778
# epoch: 885  validation loss:  0.00138701
# epoch: 886  validation loss:  0.00138624
# epoch: 887  validation loss:  0.00138548
# epoch: 888  validation loss:  0.00138472
# epoch: 889  validation loss:  0.00138396
# epoch: 890  validation loss:  0.00138321
# epoch: 891  validation loss:  0.00138245
# epoch: 892  validation loss:  0.00138171
# epoch: 893  validation loss:  0.00138097
# epoch: 894  validation loss:  0.00138023
# epoch: 895  validation loss:  0.0013795
# epoch: 896  validation loss:  0.00137877
# epoch: 897  validation loss:  0.00137804
# epoch: 898  validation loss:  0.00137732
# epoch: 899  validation loss:  0.00137661
# epoch: 900  validation loss:  0.0013759
# epoch: 901  validation loss:  0.00137519
# epoch: 902  validation loss:  0.00137449
# epoch: 903  validation loss:  0.00137379
# epoch: 904  validation loss:  0.0013731
# epoch: 905  validation loss:  0.00137241
# epoch: 906  validation loss:  0.00137173
# epoch: 907  validation loss:  0.00137105
# epoch: 908  validation loss:  0.00137038
# epoch: 909  validation loss:  0.00136971
# epoch: 910  validation loss:  0.00136905
# epoch: 911  validation loss:  0.00136839
# epoch: 912  validation loss:  0.00136775
# epoch: 913  validation loss:  0.0013671
# epoch: 914  validation loss:  0.00136646
# epoch: 915  validation loss:  0.00136582
# epoch: 916  validation loss:  0.0013652
# epoch: 917  validation loss:  0.00136458
# epoch: 918  validation loss:  0.00136396
# epoch: 919  validation loss:  0.00136335
# epoch: 920  validation loss:  0.00136274
# epoch: 921  validation loss:  0.00136214
# epoch: 922  validation loss:  0.00136155
# epoch: 923  validation loss:  0.00136096
# epoch: 924  validation loss:  0.00136038
# epoch: 925  validation loss:  0.00135981
# epoch: 926  validation loss:  0.00135924
# epoch: 927  validation loss:  0.00135867
# epoch: 928  validation loss:  0.00135812
# epoch: 929  validation loss:  0.00135756
# epoch: 930  validation loss:  0.00135702
# epoch: 931  validation loss:  0.00135648
# epoch: 932  validation loss:  0.00135595
# epoch: 933  validation loss:  0.00135542
# epoch: 934  validation loss:  0.0013549
# epoch: 935  validation loss:  0.00135438
# epoch: 936  validation loss:  0.00135387
# epoch: 937  validation loss:  0.00135337
# epoch: 938  validation loss:  0.00135287
# epoch: 939  validation loss:  0.00135238
# epoch: 940  validation loss:  0.0013519
# epoch: 941  validation loss:  0.00135142
# epoch: 942  validation loss:  0.00135095
# epoch: 943  validation loss:  0.00135048
# epoch: 944  validation loss:  0.00135002
# epoch: 945  validation loss:  0.00134956
# epoch: 946  validation loss:  0.00134912
# epoch: 947  validation loss:  0.00134867
# epoch: 948  validation loss:  0.00134823
# epoch: 949  validation loss:  0.0013478
# epoch: 950  validation loss:  0.00134738
# epoch: 951  validation loss:  0.00134696
# epoch: 952  validation loss:  0.00134654
# epoch: 953  validation loss:  0.00134614
# epoch: 954  validation loss:  0.00134573
# epoch: 955  validation loss:  0.00134533
# epoch: 956  validation loss:  0.00134494
# epoch: 957  validation loss:  0.00134455
# epoch: 958  validation loss:  0.00134417
# epoch: 959  validation loss:  0.0013438
# epoch: 960  validation loss:  0.00134342
# epoch: 961  validation loss:  0.00134306
# epoch: 962  validation loss:  0.00134269
# epoch: 963  validation loss:  0.00134234
# epoch: 964  validation loss:  0.00134199
# epoch: 965  validation loss:  0.00134165
# epoch: 966  validation loss:  0.0013413
# epoch: 967  validation loss:  0.00134097
# epoch: 968  validation loss:  0.00134063
# epoch: 969  validation loss:  0.00134031
# epoch: 970  validation loss:  0.00133998
# epoch: 971  validation loss:  0.00133967
# epoch: 972  validation loss:  0.00133936
# epoch: 973  validation loss:  0.00133905
# epoch: 974  validation loss:  0.00133875
# epoch: 975  validation loss:  0.00133845
# epoch: 976  validation loss:  0.00133815
# epoch: 977  validation loss:  0.00133786
# epoch: 978  validation loss:  0.00133757
# epoch: 979  validation loss:  0.00133729
# epoch: 980  validation loss:  0.00133701
# epoch: 981  validation loss:  0.00133674
# epoch: 982  validation loss:  0.00133647
# epoch: 983  validation loss:  0.0013362
# epoch: 984  validation loss:  0.00133594
# epoch: 985  validation loss:  0.00133568
# epoch: 986  validation loss:  0.00133543
# epoch: 987  validation loss:  0.00133517
# epoch: 988  validation loss:  0.00133492
# epoch: 989  validation loss:  0.00133468
# epoch: 990  validation loss:  0.00133444
# epoch: 991  validation loss:  0.00133421
# epoch: 992  validation loss:  0.00133397
# epoch: 993  validation loss:  0.00133374
# epoch: 994  validation loss:  0.00133351
# epoch: 995  validation loss:  0.00133329
# epoch: 996  validation loss:  0.00133307
# epoch: 997  validation loss:  0.00133285
# epoch: 998  validation loss:  0.00133263
# epoch: 999  validation loss:  0.00133242

# %% [markdown]
# # 5. Show Results

# %%
truncate = maxlen
Z = X[:1]
original = [f[i] for i in range(maxlen)]
predicted = [None for i in range(maxlen)]

for i in range(length_of_sequences -maxlen +1):
    z_ = Z[-1:]
    y_ = y.eval(session=sess, feed_dict ={x: Z[-1:],
                                          n_batch: 1})
    sequence_ = np.concatenate((z_.reshape(maxlen, n_in)[1:], y_), axis=0)\
                               .reshape(1, maxlen, n_in)
    Z = np.append(Z, sequence_, axis=0)
    predicted.append(y_.reshape(-1))

plt.rc('font', family='serif')
plt.figure()
plt.plot(toy_problem(T, ampl=0), linestyle='dotted', color='#aaaaaa')
plt.plot(original, linestyle='dashed', color='black')
plt.plot(predicted, color='black')
plt.show()

# %%
truncate = maxlen
Z = X[:1]
original = [f[i] for i in range(maxlen)]
predicted = [None for i in range(maxlen)]

for i in range(length_of_sequences -maxlen +1):
    z_ = Z[-1:]
    y_ = y.eval(session=sess, feed_dict ={x: Z[-1:],
                                          n_batch: 1})
    sequence_ = np.concatenate((z_.reshape(maxlen, n_in)[1:], y_), axis=0)\
                               .reshape(1, maxlen, n_in)
    Z = np.append(Z, sequence_, axis=0)
    predicted.append(y_.reshape(-1))

plt.rc('font', family='serif')
plt.figure()
plt.plot(toy_problem(T, ampl=0), linestyle='dotted', color='#aaaaaa')
plt.plot(original, linestyle='dashed', color='black')
plt.plot(predicted, color='black')
plt.show()

# %% [markdown]
# # 7. Inspect Variables

# %% [markdown]
# #### What happened to the variables in RNN cell?

# %%
    W = cvars[0].eval(session=sess)
    bias = cvars[1].eval(session=sess)
    print(W.shape) # Note that the first part is from the input x, the second part
                   # From the hidden state
    print(bias.shape)
# Out:
# (20, 1)
# (1, 20)

# %%
tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='RNN')
# Out:
# [<tf.Variable 'RNN/U:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/b:0' shape=(20,) dtype=float32_ref>,
#  <tf.Variable 'RNN/U/Adam:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/U/Adam_1:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W/Adam:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W/Adam_1:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/b/Adam:0' shape=(20,) dtype=float32_ref>,
#  <tf.Variable 'RNN/b/Adam_1:0' shape=(20,) dtype=float32_ref>]

# %%
tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)
# Out:
# [<tf.Variable 'V:0' shape=(20, 1) dtype=float32_ref>,
#  <tf.Variable 'c:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'RNN/U:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/b:0' shape=(20,) dtype=float32_ref>,
#  <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'V/Adam:0' shape=(20, 1) dtype=float32_ref>,
#  <tf.Variable 'V/Adam_1:0' shape=(20, 1) dtype=float32_ref>,
#  <tf.Variable 'c/Adam:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'c/Adam_1:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'RNN/U/Adam:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/U/Adam_1:0' shape=(1, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W/Adam:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/W/Adam_1:0' shape=(20, 20) dtype=float32_ref>,
#  <tf.Variable 'RNN/b/Adam:0' shape=(20,) dtype=float32_ref>,
#  <tf.Variable 'RNN/b/Adam_1:0' shape=(20,) dtype=float32_ref>]
